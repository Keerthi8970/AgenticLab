# %%
# !pip install -q langchain langchain-groq langsmith
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.3 MB/s eta 0:00:00

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "YOUR_LANGSMITH_API_KEY"
os.environ["LANGCHAIN_PROJECT"] = "Lab9-Agentic-AI"

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key="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",
    model_name="llama-3.1-8b-instant",
    temperature=0
)

question = """
A shop sells pens at 12 rupees each.
If I buy 7 and pay with 100,
how much change do I get?
Think step by step.
"""

response = llm.invoke(question)

print(response.content)
# Out:
# To find out how much change you get, let's break it down step by step:
#
# 1. The cost of 7 pens is 7 x 12 rupees = 84 rupees.
# 2. You pay with 100 rupees.
# 3. To find the change, subtract the cost of the pens from the amount you paid: 100 - 84 = 16 rupees.
#
# So, you get 16 rupees as change.
