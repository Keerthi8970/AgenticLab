# %%
# !pip install -q langchain langchain-community langchain-groq duckduckgo-search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 95.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key="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",

    model_name="llama-3.1-8b-instant",
    temperature=0.3
)

# %%
# !pip install -q ddgs langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 10.5 MB/s eta 0:00:00

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()

def search_agent(topic):
    return search.run(f"latest news about {topic}")

# %%
def summariser_agent(raw_results):
    prompt = f"""
Summarize the following news into exactly 3 short bullet points.

News:
{raw_results}
"""

    return llm.invoke(prompt).content

# %%
def report_agent(topic, summary):
    prompt = f"""
Create a Markdown report.

Title:
# News: {topic}

Summary:
{summary}
"""

    return llm.invoke(prompt).content

# %%
topic = "artificial intelligence"

raw = search_agent(topic)
summary = summariser_agent(raw)
report = report_agent(topic, summary)

with open("news_report.md", "w") as f:
    f.write(report)

print(report)
print("\nSaved as news_report.md")
# Out:
# # News: Artificial Intelligence
# =====================================
#
# ## Summary
# ---------------
#
# Here are three short bullet points summarizing the news:
#
# * Google News and other sources like Reuters and AI Weekly are providing the latest updates on artificial intelligence (AI) breakthroughs and trends.
# * The news covers various aspects of AI, including technology, regulation, ethics, business, and global impact.
# * Multiple websites, such as AI Weekly and Artificial Intelligence News, offer curated AI updates and insights, including funding, models, and applications, for professionals and enthusiasts.
#
# ## Details
# ------------
#
# ### Latest Breakthroughs and Trends
#
# Google News and other reputable sources are keeping us up-to-date on the latest artificial intelligence breakthroughs and trends. From advancements in machine learning to the development of new AI-powered tools, there's always something new to learn.
#
# ### AI Across Various Aspects
#
# The news covers a wide range of AI-related topics, including:
#
# * **Technology**: The latest advancements in AI algorithms, models, and architectures.
# * **Regulation**: Updates on AI-related laws, policies, and regulations.
# * **Ethics**: Discussions on the ethics of AI, including bias, transparency, and accountability.
# * **Business**: Insights on the business side of AI, including funding, investments, and market trends.
# * **Global Impact**: The impact of AI on society, including its effects on employment, education, and healthcare.
#
# ### Curated AI Updates and Insights
#
# For professionals and enthusiasts alike, multiple websites offer curated AI updates and insights. Some popular sources include:
#
# * **AI Weekly**: A weekly newsletter providing the latest AI news, trends, and insights.
# * **Artificial Intelligence News**: A website offering curated AI updates, including funding, models, and applications.
#
# ### Conclusion
# ----------
#
# In conclusion, the news is filled with exciting developments and trends in artificial intelligence. Whether you're a professional or enthusiast, there's always something new to learn and discover. Stay up-to-date with the latest AI news and insights to stay ahead of the curve.
#
# Saved as news_report.md
