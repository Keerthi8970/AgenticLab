# %%
# !pip install langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.9 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
import os
import getpass

os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.3
)

print("✅ Groq model connected successfully!")
# Out:
# Enter your Groq API key: ··········
# ✅ Groq model connected successfully!

# %%
task = "Write a short polite email asking my professor for a deadline extension."

draft = llm.invoke(task).content

print("----- DRAFT EMAIL -----")
print(draft)
# Out:
# ----- DRAFT EMAIL -----
# Here's a sample email:
#
# Subject: Request for Deadline Extension for [Assignment/Project]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to request a deadline extension for the [Assignment/Project] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., "unforeseen circumstances" or "additional research requirements"], I require a bit more time to complete the assignment to the best of my abilities.
#
# I am confident that with a brief extension, I will be able to submit high-quality work that meets your expectations. I am estimating that I will need an additional [Specific Number of Days] to complete the assignment.
#
# I would greatly appreciate it if you could consider my request. If there's any additional information you need from me or if you have any questions, please don't hesitate to reach out.
#
# Thank you for your understanding and support.
#
# Sincerely,
# [Your Name]

# %%
decision = input("Type APPROVED to send, or anything else to reject: ")

if decision.strip().upper() == "APPROVED":
    print("✅ Email sent!")
else:
    print("❌ Not sent. The draft was rejected.")
# Out:
# Type APPROVED to send, or anything else to reject: APPROVED
# ✅ Email sent!
